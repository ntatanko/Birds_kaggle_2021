# %%
all_500_month = {
    "SNE": [
        "acowoo",
        "ameavo",
        "amecro",
        "amegfi",
        "amekes",
        "amerob",
        "annhum",
        "astfly",
        "barswa",
        "bewwre",
        "bkhgro",
        "bknsti",
        "blugrb1",
        "bnhcow",
        "brebla",
        "brncre",
        "btywar",
        "buggna",
        "bulori",
        "bushti",
        "calqua",
        "caltow",
        "cangoo",
        "casfin",
        "casvir",
        "chbchi",
        "comyel",
        "coohaw",
        "cowscj1",
        "daejun",
        "dowwoo",
        "dusfly",
        "eucdov",
        "eursta",
        "gnttow",
        "gockin",
        "grhowl",
        "haiwoo",
        "herthr",
        "herwar",
        "houfin",
        "houwre",
        "hutvir",
        "killde",
        "larspa",
        "lazbun",
        "lesgol",
        "linspa",
        "macwar",
        "marwre",
        "mouchi",
        "moudov",
        "mouqua",
        "naswar",
        "norfli",
        "normoc",
        "nutwoo",
        "oaktit",
        "olsfly",
        "orcwar",
        "pasfly",
        "pibgre",
        "pilwoo",
        "plsvir",
        "pygnut",
        "rebnut",
        "rebsap",
        "redcro",
        "rethaw",
        "rewbla",
        "rocpig",
        "savspa",
        "saypho",
        "sonspa",
        "spotow",
        "stejay",
        "sumtan",
        "swathr",
        "towsol",
        "treswa",
        "vigswa",
        "warvir",
        "wesblu",
        "weskin",
        "wesmea",
        "westan",
        "wewpew",
        "whbnut",
        "whcspa",
        "whtspa",
        "wiltur",
        "wlswar",
        "wooduc",
        "wrenti",
        "yebcha",
        "yehbla",
    ],
    "SSW": [
        "acafly",
        "aldfly",
        "amecro",
        "amegfi",
        "amekes",
        "amered",
        "amerob",
        "amewig",
        "amtspa",
        "babwar",
        "balori",
        "barswa",
        "bawwar",
        "bcnher",
        "belkin1",
        "bkbwar",
        "bkcchi",
        "blugrb1",
        "blujay",
        "bnhcow",
        "botgra",
        "brncre",
        "brnthr",
        "brwhaw",
        "btbwar",
        "btnwar",
        "buggna",
        "buhvir",
        "buwtea",
        "cangoo",
        "canwar",
        "carchi",
        "carwre",
        "caster1",
        "cedwax",
        "chispa",
        "chswar",
        "comgol",
        "comgra",
        "comloo",
        "commer",
        "comrav",
        "comyel",
        "coohaw",
        "daejun",
        "dowwoo",
        "easblu",
        "easkin",
        "easmea",
        "easpho",
        "eastow",
        "eawpew",
        "eursta",
        "fiespa",
        "foxspa",
        "gbbgul",
        "gockin",
        "grbher3",
        "grcfly",
        "greyel",
        "grhowl",
        "grnher",
        "grycat",
        "haiwoo",
        "herthr",
        "houfin",
        "houspa",
        "houwre",
        "indbun",
        "killde",
        "laugul",
        "leafly",
        "leasan",
        "linspa",
        "lotduc",
        "magwar",
        "mallar3",
        "marwre",
        "moudov",
        "mouwar",
        "naswar",
        "nocall",
        "norcar",
        "norfli",
        "normoc",
        "norpar",
        "norwat",
        "nrwswa",
        "olsfly",
        "orcwar",
        "osprey",
        "ovenbi1",
        "palwar",
        "phivir",
        "pibgre",
        "pilwoo",
        "pinsis",
        "prowar",
        "purfin",
        "rebnut",
        "rebwoo",
        "redcro",
        "reevir1",
        "reshaw",
        "rethaw",
        "rewbla",
        "ribgul",
        "robgro",
        "royter1",
        "rthhum",
        "ruckin",
        "sancra",
        "sander",
        "savspa",
        "scatan",
        "semplo",
        "solsan",
        "sonspa",
        "sposan",
        "swaspa",
        "swathr",
        "tenwar",
        "treswa",
        "tuftit",
        "veery",
        "warvir",
        "wesmea",
        "whbnut",
        "whcspa",
        "whevir",
        "whtspa",
        "wilfly",
        "wilsni1",
        "wiltur",
        "wlswar",
        "wooduc",
        "woothr",
        "yebcha",
        "yebfly",
        "yebsap",
        "yerwar",
        "yetvir",
    ],
    "COR": [
        "acafly",
        "balori",
        "banana",
        "banwre1",
        "bawwar",
        "baywre1",
        "bkmtou1",
        "blkpho",
        "blugrb1",
        "bncfly",
        "bobfly1",
        "brbmot1",
        "brnjay",
        "brratt1",
        "bucmot2",
        "burwar1",
        "butsal1",
        "canwar",
        "chbant1",
        "chswar",
        "clcrob",
        "cocwoo1",
        "compau",
        "cotfly1",
        "crfpar",
        "ducfly",
        "easmea",
        "eawpew",
        "fepowl",
        "gbwwre1",
        "grbani",
        "grekis",
        "grhcha1",
        "grtgra",
        "hofwoo1",
        "incdov",
        "kebtou1",
        "leafly",
        "lesgol",
        "lobgna5",
        "lotman1",
        "melbla1",
        "monoro1",
        "mouwar",
        "nocall",
        "obnthr1",
        "olsfly",
        "orbspa1",
        "orcpar",
        "orfpar",
        "pabspi1",
        "paltan1",
        "plawre1",
        "rawwre1",
        "rcatan1",
        "reevir1",
        "rtlhum",
        "rubpep1",
        "rubwre1",
        "rucspa1",
        "rucwar",
        "runwre1",
        "scbwre1",
        "socfly1",
        "soulap1",
        "sthwoo1",
        "trogna1",
        "tromoc",
        "veery",
        "wbwwre1",
        "wesant1",
        "wewpew",
        "whcpar",
        "yebori1",
        "yegvir",
        "yehcar1",
        "yeteup1",
    ],
    "COL": [
        "acafly",
        "acowoo",
        "amekes",
        "amered",
        "andsol1",
        "azaspi1",
        "banana",
        "barant1",
        "bawswa1",
        "baywre1",
        "bbwduc",
        "bkbwar",
        "bkmtou1",
        "blbgra1",
        "blbthr1",
        "blcjay1",
        "blctan1",
        "blhpar1",
        "blsspa1",
        "bobfly1",
        "brbmot1",
        "brcvir1",
        "brratt1",
        "brwhaw",
        "bugtan",
        "burwar1",
        "buwtea",
        "canwar",
        "ccbfin",
        "chbant1",
        "chbwre1",
        "chcant2",
        "clcrob",
        "cocwoo1",
        "colcha1",
        "coltro1",
        "compau",
        "compot1",
        "cotfly1",
        "creoro1",
        "ducfly",
        "easmea",
        "eawpew",
        "flrtan1",
        "gartro1",
        "gbwwre1",
        "gcrwar",
        "gocfly1",
        "goftyr1",
        "gohque1",
        "goowoo1",
        "grasal1",
        "grekis",
        "grethr1",
        "gretin1",
        "greyel",
        "grnjay",
        "higmot1",
        "houwre",
        "killde",
        "laufal1",
        "lesgol",
        "lesvio1",
        "linwoo1",
        "littin1",
        "lobgna5",
        "mallar3",
        "mastro1",
        "meapar",
        "mouela1",
        "norwat",
        "obnthr1",
        "ocbfly1",
        "orbeup1",
        "orbspa1",
        "orcpar",
        "pabspi1",
        "pavpig2",
        "pibgre",
        "pirfly1",
        "plupig2",
        "prowar",
        "putfru1",
        "rehbar1",
        "roahaw",
        "rocpig",
        "royter1",
        "rtlhum",
        "ruboro1",
        "rubpep1",
        "rubwre1",
        "rucspa1",
        "rucwar",
        "rucwar1",
        "rudpig",
        "rugdov",
        "rumfly1",
        "rutjac1",
        "saffin",
        "scbwre1",
        "scptyr1",
        "scrtan1",
        "sibtan2",
        "sltred",
        "smbani",
        "sobtyr1",
        "solsan",
        "soulap1",
        "sposan",
        "spvear1",
        "squcuc1",
        "sthant1",
        "strcuc1",
        "strfly1",
        "strsal1",
        "sumtan",
        "swathr",
        "tenwar",
        "thbeup1",
        "thswar1",
        "trogna1",
        "trokin",
        "tromoc",
        "tropar",
        "wbwwre1",
        "webwoo1",
        "wesant1",
        "wewpew",
        "whbman1",
        "whiwre1",
        "whtdov",
        "whwbec1",
        "wilfly",
        "y00475",
        "yebela1",
        "yebori1",
        "yebsee1",
        "yefgra1",
        "yehcar1",
        "yelwar",
        "yeofly1",
    ],
    "Total": [
        "acafly",
        "acowoo",
        "aldfly",
        "ameavo",
        "amecro",
        "amegfi",
        "amekes",
        "amered",
        "amerob",
        "amewig",
        "amtspa",
        "andsol1",
        "annhum",
        "astfly",
        "azaspi1",
        "babwar",
        "balori",
        "banana",
        "banwre1",
        "barant1",
        "barswa",
        "bawswa1",
        "bawwar",
        "baywre1",
        "bbwduc",
        "bcnher",
        "belkin1",
        "bewwre",
        "bkbwar",
        "bkcchi",
        "bkhgro",
        "bkmtou1",
        "bknsti",
        "blbgra1",
        "blbthr1",
        "blcjay1",
        "blctan1",
        "blhpar1",
        "blkpho",
        "blsspa1",
        "blugrb1",
        "blujay",
        "bncfly",
        "bnhcow",
        "bobfly1",
        "botgra",
        "brbmot1",
        "brcvir1",
        "brebla",
        "brncre",
        "brnjay",
        "brnthr",
        "brratt1",
        "brwhaw",
        "btbwar",
        "btnwar",
        "btywar",
        "bucmot2",
        "buggna",
        "bugtan",
        "buhvir",
        "bulori",
        "burwar1",
        "bushti",
        "butsal1",
        "buwtea",
        "calqua",
        "caltow",
        "cangoo",
        "canwar",
        "carchi",
        "carwre",
        "casfin",
        "caster1",
        "casvir",
        "ccbfin",
        "cedwax",
        "chbant1",
        "chbchi",
        "chbwre1",
        "chcant2",
        "chispa",
        "chswar",
        "clcrob",
        "cocwoo1",
        "colcha1",
        "coltro1",
        "comgol",
        "comgra",
        "comloo",
        "commer",
        "compau",
        "compot1",
        "comrav",
        "comyel",
        "coohaw",
        "cotfly1",
        "cowscj1",
        "creoro1",
        "crfpar",
        "daejun",
        "dowwoo",
        "ducfly",
        "dusfly",
        "easblu",
        "easkin",
        "easmea",
        "easpho",
        "eastow",
        "eawpew",
        "eucdov",
        "eursta",
        "fepowl",
        "fiespa",
        "flrtan1",
        "foxspa",
        "gartro1",
        "gbbgul",
        "gbwwre1",
        "gcrwar",
        "gnttow",
        "gocfly1",
        "gockin",
        "goftyr1",
        "gohque1",
        "goowoo1",
        "grasal1",
        "grbani",
        "grbher3",
        "grcfly",
        "grekis",
        "grethr1",
        "gretin1",
        "greyel",
        "grhcha1",
        "grhowl",
        "grnher",
        "grnjay",
        "grtgra",
        "grycat",
        "haiwoo",
        "herthr",
        "herwar",
        "higmot1",
        "hofwoo1",
        "houfin",
        "houspa",
        "houwre",
        "hutvir",
        "incdov",
        "indbun",
        "kebtou1",
        "killde",
        "larspa",
        "laufal1",
        "laugul",
        "lazbun",
        "leafly",
        "leasan",
        "lesgol",
        "lesvio1",
        "linspa",
        "linwoo1",
        "littin1",
        "lobgna5",
        "lotduc",
        "lotman1",
        "macwar",
        "magwar",
        "mallar3",
        "marwre",
        "mastro1",
        "meapar",
        "melbla1",
        "monoro1",
        "mouchi",
        "moudov",
        "mouela1",
        "mouqua",
        "mouwar",
        "naswar",
        "nocall",
        "norcar",
        "norfli",
        "normoc",
        "norpar",
        "norwat",
        "nrwswa",
        "nutwoo",
        "oaktit",
        "obnthr1",
        "ocbfly1",
        "olsfly",
        "orbeup1",
        "orbspa1",
        "orcpar",
        "orcwar",
        "orfpar",
        "osprey",
        "ovenbi1",
        "pabspi1",
        "paltan1",
        "palwar",
        "pasfly",
        "pavpig2",
        "phivir",
        "pibgre",
        "pilwoo",
        "pinsis",
        "pirfly1",
        "plawre1",
        "plsvir",
        "plupig2",
        "prowar",
        "purfin",
        "putfru1",
        "pygnut",
        "rawwre1",
        "rcatan1",
        "rebnut",
        "rebsap",
        "rebwoo",
        "redcro",
        "reevir1",
        "rehbar1",
        "reshaw",
        "rethaw",
        "rewbla",
        "ribgul",
        "roahaw",
        "robgro",
        "rocpig",
        "royter1",
        "rthhum",
        "rtlhum",
        "ruboro1",
        "rubpep1",
        "rubwre1",
        "ruckin",
        "rucspa1",
        "rucwar",
        "rucwar1",
        "rudpig",
        "rugdov",
        "rumfly1",
        "runwre1",
        "rutjac1",
        "saffin",
        "sancra",
        "sander",
        "savspa",
        "saypho",
        "scatan",
        "scbwre1",
        "scptyr1",
        "scrtan1",
        "semplo",
        "sibtan2",
        "sltred",
        "smbani",
        "sobtyr1",
        "socfly1",
        "solsan",
        "sonspa",
        "soulap1",
        "sposan",
        "spotow",
        "spvear1",
        "squcuc1",
        "stejay",
        "sthant1",
        "sthwoo1",
        "strcuc1",
        "strfly1",
        "strsal1",
        "sumtan",
        "swaspa",
        "swathr",
        "tenwar",
        "thbeup1",
        "thswar1",
        "towsol",
        "treswa",
        "trogna1",
        "trokin",
        "tromoc",
        "tropar",
        "tuftit",
        "veery",
        "vigswa",
        "warvir",
        "wbwwre1",
        "webwoo1",
        "wesant1",
        "wesblu",
        "weskin",
        "wesmea",
        "westan",
        "wewpew",
        "whbman1",
        "whbnut",
        "whcpar",
        "whcspa",
        "whevir",
        "whiwre1",
        "whtdov",
        "whtspa",
        "whwbec1",
        "wilfly",
        "wilsni1",
        "wiltur",
        "wlswar",
        "wooduc",
        "woothr",
        "wrenti",
        "y00475",
        "yebcha",
        "yebela1",
        "yebfly",
        "yebori1",
        "yebsap",
        "yebsee1",
        "yefgra1",
        "yegvir",
        "yehbla",
        "yehcar1",
        "yelwar",
        "yeofly1",
        "yerwar",
        "yeteup1",
        "yetvir",
    ],
}

# %%
all_500 = {
    # * Within 500.0 miles from SNE (Sierra Nevada, California, USA @ 38.49, -119.95) between 201805 and 201805 (+-1.0 months):
    "SNE": [
        "amekes",
        "amerob",
        "astfly",
        "bkhgro",
        "bnhcow",
        "bulori",
        "calqua",
        "casfin",
        "caster1",
        "casvir",
        "chswar",
        "clanut",
        "comyel",
        "cowscj1",
        "dusfly",
        "eucdov",
        "gnttow",
        "gocspa",
        "haiwoo",
        "herwar",
        "houfin",
        "houwre",
        "killde",
        "larspa",
        "lazbun",
        "lesgol",
        "linspa",
        "macwar",
        "mouqua",
        "norfli",
        "normoc",
        "nutwoo",
        "oaktit",
        "orcwar",
        "plsvir",
        "rebnut",
        "reshaw",
        "rethaw",
        "savspa",
        "sonspa",
        "sposan",
        "spotow",
        "stejay",
        "swathr",
        "towsol",
        "treswa",
        "warvir",
        "weskin",
        "westan",
        "wewpew",
        "whcspa",
        "wlswar",
        "wooduc",
    ],
    # * Within 500.0 miles from SSW (Ithaca, New York, USA @ 42.47, -76.45) between 201702 and 201708 (+-1.0 months):
    "SSW": [
        "acafly",
        "aldfly",
        "amecro",
        "amegfi",
        "amered",
        "amerob",
        "babwar",
        "balori",
        "barswa",
        "belkin1",
        "bkbwar",
        "bkcchi",
        "blujay",
        "bnhcow",
        "brncre",
        "brnthr",
        "btbwar",
        "buggna",
        "cangoo",
        "canwar",
        "carchi",
        "carwre",
        "chispa",
        "chswar",
        "comgra",
        "comloo",
        "comrav",
        "comyel",
        "daejun",
        "dowwoo",
        "easblu",
        "easpho",
        "eastow",
        "eawpew",
        "fiespa",
        "foxspa",
        "gockin",
        "grbher3",
        "grycat",
        "haiwoo",
        "herthr",
        "houwre",
        "indbun",
        "killde",
        "magwar",
        "mallar3",
        "marwre",
        "nocall",
        "norcar",
        "norfli",
        "normoc",
        "norpar",
        "norwat",
        "ovenbi1",
        "pilwoo",
        "prowar",
        "rebwoo",
        "reevir1",
        "rewbla",
        "robgro",
        "scatan",
        "sonspa",
        "swaspa",
        "treswa",
        "tuftit",
        "veery",
        "warvir",
        "whbnut",
        "whevir",
        "whtspa",
        "wilfly",
        "wlswar",
        "woothr",
        "yebsap",
        "yetvir",
    ],
    # * Within 500.0 miles from COR (Alajuela, San Ramón, Costa Rica @ 10.12, -84.51) between 201909 and 201910 (+-1.0 months):
    "COR": [
        "bobfly1",
        "brcvir1",
        "brnjay",
        "bucmot2",
        "clcrob",
        "crfpar",
        "grasal1",
        "grekis",
        "grhcha1",
        "grtgra",
        "hofwoo1",
        "leafly",
        "lotman1",
        "melbla1",
        "nocall",
        "obnthr1",
        "ocbfly1",
        "orcpar",
        "orfpar",
        "plawre1",
        "reevir1",
        "rehbar1",
        "rtlhum",
        "rubwre1",
        "rucwar",
        "runwre1",
        "scbwre1",
        "sthwoo1",
        "tropar",
        "veery",
        "wesant1",
        "whcpar",
        "yehcar1",
    ],
    # * Within 500.0 miles from COL (Jardín, Departamento de Antioquia, Colombia @ 5.57, -75.85) between 201909 and 201911 (+-1.0 months):
    "COL": [
        "andsol1",
        "azaspi1",
        "banana",
        "barant1",
        "bkmtou1",
        "blcjay1",
        "blsspa1",
        "brcvir1",
        "burwar1",
        "chbwre1",
        "chcant2",
        "colcha1",
        "coltro1",
        "compot1",
        "eawpew",
        "fepowl",
        "gartro1",
        "grasal1",
        "grekis",
        "houwre",
        "lesvio1",
        "obnthr1",
        "orbspa1",
        "orcpar",
        "pabspi1",
        "pirfly1",
        "roahaw",
        "rubpep1",
        "rucspa1",
        "rumfly1",
        "scbwre1",
        "scptyr1",
        "soulap1",
        "spvear1",
        "strsal1",
        "thbeup1",
        "trogna1",
        "tromoc",
        "whiwre1",
        "whtdov",
        "whwbec1",
        "wilfly",
    ],
    "total": [
        "acafly",
        "aldfly",
        "amecro",
        "amegfi",
        "amekes",
        "amered",
        "amerob",
        "andsol1",
        "astfly",
        "azaspi1",
        "babwar",
        "balori",
        "banana",
        "barant1",
        "barswa",
        "belkin1",
        "bkbwar",
        "bkcchi",
        "bkhgro",
        "bkmtou1",
        "blcjay1",
        "blsspa1",
        "blujay",
        "bnhcow",
        "bobfly1",
        "brcvir1",
        "brncre",
        "brnjay",
        "brnthr",
        "btbwar",
        "bucmot2",
        "buggna",
        "bulori",
        "burwar1",
        "calqua",
        "cangoo",
        "canwar",
        "carchi",
        "carwre",
        "casfin",
        "caster1",
        "casvir",
        "chbwre1",
        "chcant2",
        "chispa",
        "chswar",
        "clanut",
        "clcrob",
        "colcha1",
        "coltro1",
        "comgra",
        "comloo",
        "compot1",
        "comrav",
        "comyel",
        "cowscj1",
        "crfpar",
        "daejun",
        "dowwoo",
        "dusfly",
        "easblu",
        "easpho",
        "eastow",
        "eawpew",
        "eucdov",
        "fepowl",
        "fiespa",
        "foxspa",
        "gartro1",
        "gnttow",
        "gockin",
        "gocspa",
        "grasal1",
        "grbher3",
        "grekis",
        "grhcha1",
        "grtgra",
        "grycat",
        "haiwoo",
        "herthr",
        "herwar",
        "hofwoo1",
        "houfin",
        "houwre",
        "indbun",
        "killde",
        "larspa",
        "lazbun",
        "leafly",
        "lesgol",
        "lesvio1",
        "linspa",
        "lotman1",
        "macwar",
        "magwar",
        "mallar3",
        "marwre",
        "melbla1",
        "mouqua",
        "nocall",
        "norcar",
        "norfli",
        "normoc",
        "norpar",
        "norwat",
        "nutwoo",
        "oaktit",
        "obnthr1",
        "ocbfly1",
        "orbspa1",
        "orcpar",
        "orcwar",
        "orfpar",
        "ovenbi1",
        "pabspi1",
        "pilwoo",
        "pirfly1",
        "plawre1",
        "plsvir",
        "prowar",
        "rebnut",
        "rebwoo",
        "reevir1",
        "rehbar1",
        "reshaw",
        "rethaw",
        "rewbla",
        "roahaw",
        "robgro",
        "rtlhum",
        "rubpep1",
        "rubwre1",
        "rucspa1",
        "rucwar",
        "rumfly1",
        "runwre1",
        "savspa",
        "scatan",
        "scbwre1",
        "scptyr1",
        "sonspa",
        "soulap1",
        "sposan",
        "spotow",
        "spvear1",
        "stejay",
        "sthwoo1",
        "strsal1",
        "swaspa",
        "swathr",
        "thbeup1",
        "towsol",
        "treswa",
        "trogna1",
        "tromoc",
        "tropar",
        "tuftit",
        "veery",
        "warvir",
        "wesant1",
        "weskin",
        "westan",
        "wewpew",
        "whbnut",
        "whcpar",
        "whcspa",
        "whevir",
        "whiwre1",
        "whtdov",
        "whtspa",
        "whwbec1",
        "wilfly",
        "wlswar",
        "wooduc",
        "woothr",
        "yebsap",
        "yehcar1",
        "yetvir",
    ],
}

# %%
import json
out_file = open("/app/_data/my/500_miles_monts.json", "w")
json.dump(all_500_month, out_file, sort_keys = True)
out_file.close()

# %%
with open("/app/_data/my/500_miles_monts.json", "r") as r:
    miles_500 = json.load(r)

# %%
miles_500.keys()
# Out:
# dict_keys(['COL', 'COR', 'SNE', 'SSW', 'Total'])

# %%
import kaggle
! kaggle datasets init -p /app/_data/my/
# Out:
# ...
# Data package template written to: /app/_data/my/dataset-metadata.json

# %%
! kaggle datasets create -p /app/_data/my/
# Out:
# ...
# Starting upload for file dict_birds.json
# 100%|██████████████████████████████████████| 7.52k/7.52k [00:02<00:00, 3.75kB/s]
# Upload successful: dict_birds.json (8KB)
# Starting upload for file coord_sites.csv
# 100%|███████████████████████████████████████████| 209/209 [00:02<00:00, 81.2B/s]
# Upload successful: coord_sites.csv (209B)
# Starting upload for file 500_miles_monts.json
# 100%|██████████████████████████████████████| 7.98k/7.98k [00:02<00:00, 3.29kB/s]
# Upload successful: 500_miles_monts.json (8KB)
# Starting upload for file 500_miles.json
# 100%|██████████████████████████████████████| 3.87k/3.87k [00:01<00:00, 2.94kB/s]
# Upload successful: 500_miles.json (4KB)
# Skipping folder: .ipynb_checkpoints; use '--dir-mode' to upload folders
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/nataliayurasova/BirdsAdditionalData
