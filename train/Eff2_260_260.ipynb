# %%
import os
import shutil
import warnings

import numpy as np
import pandas as pd
import torchaudio

warnings.filterwarnings(action="ignore")
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
import json

import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_addons as tfa
import torch

# %matplotlib inline
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from torchaudio.transforms import MelSpectrogram
from tqdm import tqdm

from src.MEL_Gen_Aug_Dict import MEL_Gen, Mel_Provider
from src.prepare_dataset import (
    choose_ids,
    make_dict_birds,
    make_intervals,
    make_intervals_upsampling,
    prepare_dataset,
)

# %%
SEED = 37
IMG_SIZE = 260
N_MELS = 260
SAMPLE_RATE = 32000
N_FFT = 2048
SIGNAL_LENGTH = 5
FREQ_MIN = 0
FREQ_MAX = 15000
WIN_LENGHT = 1024
BATCH_SIZE = 200
list_drop = [
    "XC509721.ogg",
    "XC428067.ogg",
    "XC523831.ogg",
    "XC523960.ogg",
    "XC237870.ogg",
    "XC129924.ogg",
    "XC576851.ogg",
    "XC579430.ogg",
    "XC590621.ogg",
]

# %%
config = {
    "SEED": 37,
    "IMG_SIZE": 260,
    "N_MELS": 260,
    "SAMPLE_RATE": 32000,
    "N_FFT": 2048,
    "SIGNAL_LENGTH": 5,
    "FREQ_MIN": 0,
    "FREQ_MAX": 15000,
    "WIN_LENGHT": 1024,
    "NOTE_PATH": '/app/sandbox/Eff2_260_260_d6_2.ipynb',
    "MODEL_PATH": "/app/_data/models/dict_features/Eff2_260_260_1/",
    "IMG_DTYPE": "uint8",
    "SIN_COS_IMG": False,
}
file_json = open("/app/_data/models/dict_features/Eff2_260_260_1/config.json", "w")
json.dump(config, file_json)
file_json.close()

# %%
nocall = pd.read_csv("/app/_data/labels_nocall/all_nocalls.csv")

all_audio = pd.read_csv("/app/_data/all_audio_initial.csv")
all_audio = all_audio.query("filename not in @list_drop").reset_index(drop=True)
all_audio = all_audio.query("year >=1980 and year<=2021").reset_index(drop=True)
all_audio = all_audio.query("rating >=2.5").reset_index(drop=True)

all_audio.shape

# dict_birds and weights

all_audio = all_audio[all_audio["rating"] >= 3]

all_audio.shape

dict_birds, all_audio = make_dict_birds(all_audio, secondary=True)
file_json = open("/app/_data/models/dict_features/Eff2_260_260_1/dict_birds.json", "w")
json.dump(dict_birds, file_json)
file_json.close()
len(dict_birds)
# Out:
# (59647, 28)
# (56165, 28)
# 398

# %%
dict_weights = (1 / all_audio["primary_label"].value_counts()).to_dict()
all_audio["class_weights"] = all_audio["primary_label"].replace(dict_weights)
all_audio["class_weights"] = all_audio["class_weights"] * all_audio["rating"]

short_audio = all_audio[all_audio["rating"] != 6].reset_index(
    drop=True
)  # only short audio
train_sondscapes = all_audio[all_audio["rating"] == 6].reset_index(
    drop=True
)  # only train_soundscapes
short_audio.shape
train_sondscapes.shape


## calls

short_audio_0_20 = short_audio[short_audio["duration"] < 19]
short_audio_20_30 = short_audio[
    (short_audio["duration"] >= 19) & (short_audio["duration"] <= 30)
]
short_audio_30 = short_audio[short_audio["duration"] > 30]

short_audio_20_30["duration"] = short_audio_20_30["duration"] - 4
short_audio_30["duration"] = short_audio_30["duration"] - 7

short_audio = pd.concat(
    [short_audio_0_20, short_audio_20_30, short_audio_30], axis=0, ignore_index=True
)

short_audio.shape

# Make intervals for short audio

array_for_cut = short_audio[["filename", "duration", "class_weights"]].values

birds_intervals = make_intervals(array_for_cut, 5, max_intervals=150, max_lenght=300)
birds_intervals = birds_intervals.sample(frac=1, random_state=SEED)
birds_intervals.shape

birds_intervals["row_id"] = birds_intervals.index
birds_intervals["filename"].value_counts()

dict_w = pd.DataFrame((1 / birds_intervals["filename"].value_counts()))
dict_w.columns = ["weights"]
dict_w["filename"] = dict_w.index

birds_intervals = birds_intervals.merge(dict_w, on="filename", how="left")

birds_intervals_sample = birds_intervals.sample(
    n=700000, weights="weights", random_state=SEED
)

birds_intervals_sample = birds_intervals_sample.sample(
    n=500000, weights="class_weights", random_state=SEED
)

birds_intervals_sample[birds_intervals_sample["filename"] == "XC196037.ogg"]

short_audio = birds_intervals_sample.merge(
    short_audio[
        [
            "filename",
            "primary_label",
            "secondary_labels",
            "label_id",
            "secondary_labels_id",
            "duration",
            "rating",
            "year",
            "file_path",
            "frames",
            "sin_month",
            "cos_month",
            "sin_longitude",
            "cos_longitude",
            "latitude",
            "norm_latitude",
            "date",
        ]
    ],
    on="filename",
    how="left",
)

short_audio["filename"].value_counts()

short_audio["end_sec"] = short_audio["end_sec"].apply(lambda x: x if x > 5 else 5)

short_audio["start_sec"] = short_audio["end_sec"] - 5

short_audio["primary_label"].value_counts()



# nocall

nocall = nocall.drop_duplicates()

nocall["file_path"] = nocall["file_path"].str.replace("birdclef-2021/", "")

nocall = nocall[~nocall["file_path"].str.contains("train_soundscapes")].reset_index(
    drop=True
)

soundscapes_nocall = all_audio[all_audio["file_path"].str.contains("train_soundscapes")]
soundscapes_nocall = soundscapes_nocall[soundscapes_nocall["primary_label"] == "nocall"]

dict_w = (1 / nocall["filename"].value_counts()).to_dict()
nocall["weights"] = nocall["filename"].replace(dict_w)

nocall_sample = nocall.sample(1200, random_state=SEED, weights="weights")

nocall_sample["filename"].value_counts()

nocall_sample = nocall_sample.merge(
    all_audio[
        [
            "filename",
            "rating",
            "year",
            "sin_month",
            "cos_month",
            "sin_longitude",
            "cos_longitude",
            "latitude",
            "norm_latitude",
            "class_weights",
        ]
    ],
    on="filename",
    how="left",
)

nocall_sample = nocall_sample[
    [
        "filename",
        "row_id",
        "start_sec",
        "end_sec",
        "file_path",
        "duration",
        "rating",
        "year",
        "sin_month",
        "cos_month",
        "sin_longitude",
        "cos_longitude",
        "latitude",
        "norm_latitude",
        "class_weights",
    ]
]
soundscapes_nocall = soundscapes_nocall[
    [
        "filename",
        "row_id",
        "start_sec",
        "end_sec",
        "file_path",
        "duration",
        "rating",
        "year",
        "sin_month",
        "cos_month",
        "sin_longitude",
        "cos_longitude",
        "latitude",
        "norm_latitude",
        "class_weights",
    ]
]

soundscapes_nocall["duration"] = 600

all_nocall = pd.concat([nocall_sample, soundscapes_nocall], axis=0, ignore_index=True)

all_nocall["label_id"] = dict_birds["nocall"]
all_nocall = all_nocall.sample(frac=1, random_state=SEED).reset_index(drop=True)

all_nocall.isna().sum()
all_nocall = all_nocall.dropna(axis=0)
all_nocall["secondary_labels_id"] = np.nan
all_nocall["year"].describe()



# concat

final_audio = (
    pd.concat(
        [short_audio, all_nocall],
        axis=0,
        ignore_index=True,
    )
    .sample(frac=1, random_state=SEED)
    .reset_index(drop=True)
)
final_audio.shape

final_audio["primary_label"].value_counts().tail(20)

#  upsampling


rare_birds = list(final_audio["primary_label"].value_counts().tail(20).index.values)

df = pd.DataFrame(columns=["end_sec", "class_weights", "filename"])
for bird in rare_birds:
    rare_bird_filenames = (
        all_audio.query("primary_label ==@bird")["filename"].unique().tolist()
    )
    rare_array = all_audio.query(
        "primary_label ==@bird and rating!=0 and rating!=6 and filename in @rare_bird_filenames"
    )[["filename", "duration", "class_weights"]].values
    intervals = make_intervals_upsampling(rare_array, sum_intervals=600)
    df = pd.concat([df, intervals], axis=0)

df

df["filename"].unique().shape

df["row_id"] = df.index
df = df.merge(
    all_audio[
        [
            "filename",
            "primary_label",
            "secondary_labels",
            "label_id",
            "secondary_labels_id",
            "duration",
            "rating",
            "year",
            "file_path",
            "frames",
            "sin_month",
            "cos_month",
            "sin_longitude",
            "cos_longitude",
            "latitude",
            "norm_latitude",
            "date",
        ]
    ],
    on="filename",
    how="left",
)
df["end_sec"] = df["end_sec"].apply(lambda x: x if x > 5 else 5)
df["start_sec"] = df["end_sec"] - 5

df["primary_label"].unique().shape

final_audio = (
    pd.concat(
        [final_audio, df],
        axis=0,
        ignore_index=True,
    )
    .sample(frac=1, random_state=SEED)
    .reset_index(drop=True)
)
final_audio.shape

final_audio["primary_label"].value_counts().tail(20)

final_audio['secondary_labels_id'] = final_audio['secondary_labels_id'].replace('',np.nan)

final_audio['secondary_labels_id'].unique()

final_audio.to_csv(config['MODEL_PATH']+'final_audio.csv', index=False)

# %%
# final_audio=pd.read_csv(config['MODEL_PATH']+'final_audio.csv')

# %%
train, valid = train_test_split(final_audio, train_size=0.85, random_state=SEED)
train = train.reset_index(drop=True)
valid = valid.reset_index(drop=True)

# %% [markdown]
# # MEL_Gen

# %%
NUM_CLASSES = len(dict_birds)
BATCH_SIZE = 200

# %%
NUM_CLASSES
# Out:
# 398

# %%
mel_pr = Mel_Provider(
    n_fft=N_FFT,
    win_length=WIN_LENGHT,
    n_mels=N_MELS,
    sample_rate=SAMPLE_RATE,
    mel_image_size=IMG_SIZE,
    min_frequency=FREQ_MIN,
    max_frequency=FREQ_MAX,
    signal_lenght=SIGNAL_LENGTH,
)

# %%
gen_train = MEL_Gen(
    df=train,
    n_mels=N_MELS,
    seed=SEED,
    sin_cos_img=False,
    sample_rate=SAMPLE_RATE,
    mel_image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    n_classes=NUM_CLASSES,
    signal_lenght=SIGNAL_LENGTH,
    mel_provider=mel_pr,
    nocall_label_id=dict_birds["nocall"],
    wave_dir="/app/_data/npy/waves_npy/",
    short_mel_dir="/app/_data/npy/mels_260_260_uint8/",
    convert_to_rgb=True,
    shuffle=True,
    return_primary_labels=False,
    return_concat_labels=True,
    augment=False,
    rand_aug=False,
    img_dtype="uint8",
    secondary_coeff=0.3,
)
gen_valid = MEL_Gen(
    df=valid,
    n_mels=N_MELS,
    seed=SEED,
    sin_cos_img=False,
    nocall_label_id=dict_birds["nocall"],
    sample_rate=SAMPLE_RATE,
    mel_image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    n_classes=NUM_CLASSES,
    signal_lenght=SIGNAL_LENGTH,
    mel_provider=mel_pr,
    wave_dir="/app/_data/npy/waves_npy/",
    short_mel_dir="/app/_data/npy/mels_260_260_uint8/",
    convert_to_rgb=True,
    shuffle=False,
    return_primary_labels=False,
    return_concat_labels=True,
    augment=False,
    img_dtype="uint8",
    secondary_coeff=0.3,
)

# %% [markdown]
# # model

# %%
def get_model():
    input_mel = keras.Input(shape=(N_MELS, IMG_SIZE, 3), name="mel")
    base_model = keras.applications.EfficientNetB2(
        weights="imagenet", include_top=False
    )
    x_mel = base_model(input_mel)
    x_mel = keras.layers.GlobalAveragePooling2D(name="avg_pool")(x_mel)

    input_data = keras.Input(shape=6, name="data")
    x_features = keras.layers.Dense(32, activation="relu", name='dense_data_1')(input_data)
    x_features = keras.layers.Dense(32, activation="relu", name='dense_data_2')(x_features)
    x_features = keras.layers.Dense(32, activation="relu", name='dense_data_3')(x_features)
    x = keras.layers.Concatenate(axis=1, name="all",)(
        [
            x_mel,
            x_features,
        ]
    )
    outputs = keras.layers.Dense(len(dict_birds), activation="sigmoid")(x)
    model = keras.Model(
        inputs=[input_mel, input_data], outputs=outputs
    )
    model.compile(
        loss="binary_crossentropy",
        optimizer=Adam(lr=0.0005),
        metrics=[
            "acc",
            keras.metrics.Recall(),
            keras.metrics.Precision(),
            tfa.metrics.F1Score(num_classes=30, average="micro"),
        ],
    )
    return model


policy = keras.mixed_precision.experimental.Policy("mixed_float16")
keras.mixed_precision.experimental.set_policy(policy)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3090, compute capability 8.6

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_f1_score",
        patience=12,
        restore_best_weights=True,
        verbose=1,
        mode="max",
    ),
    keras.callbacks.ModelCheckpoint(
        config['MODEL_PATH']+"Eff2_260_260_d6_2.h5",
        monitor="val_f1_score",
        verbose=1,
        save_best_only=True,
        save_weights_only=False,
        mode="max",
        save_freq="epoch",
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_f1_score",
        factor=0.9,
        patience=5,
        verbose=1,
        mode="max",
        min_delta=1e-4,
        min_lr=0.00000001,
    ),
    keras.callbacks.TensorBoard(log_dir="/app/.tensorboard/Eff2_260_260_2/", histogram_freq=0),
    keras.callbacks.experimental.BackupAndRestore(config['MODEL_PATH']+"backup/"),
    keras.callbacks.TerminateOnNaN(),
]

# %%
model = get_model()
history = model.fit(
    gen_train,
    validation_data=gen_valid,
    epochs=100,
    steps_per_epoch=train.shape[0] // BATCH_SIZE-1,
    validation_steps=valid.shape[0] // BATCH_SIZE-1,
    verbose=1,
    workers=20,
    max_queue_size=3000,
    callbacks=callbacks,
)
# Out:
# Epoch 2/100
#    1/2191 [..............................] - ETA: 0s - loss: 0.0102 - acc: 0.6000 - recall: 0.1969 - precision: 0.8721 - f1_score: 0.5402WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0080 - acc: 0.6845 - recall: 0.3070 - precision: 0.9091 - f1_score: 0.6170
# Epoch 00002: val_f1_score improved from -inf to 0.66425, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1822s 831ms/step - loss: 0.0080 - acc: 0.6845 - recall: 0.3070 - precision: 0.9091 - f1_score: 0.6170 - val_loss: 0.0070 - val_acc: 0.7381 - val_recall: 0.3436 - val_precision: 0.9295 - val_f1_score: 0.6642
# Epoch 3/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0061 - acc: 0.7896 - recall: 0.3874 - precision: 0.9374 - f1_score: 0.7089
# Epoch 00003: val_f1_score improved from 0.66425 to 0.72154, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1816s 829ms/step - loss: 0.0061 - acc: 0.7896 - recall: 0.3874 - precision: 0.9374 - f1_score: 0.7089 - val_loss: 0.0057 - val_acc: 0.8034 - val_recall: 0.4179 - val_precision: 0.9293 - val_f1_score: 0.7215
# Epoch 4/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0049 - acc: 0.8541 - recall: 0.4386 - precision: 0.9532 - f1_score: 0.7644
# Epoch 00004: val_f1_score improved from 0.72154 to 0.75909, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1814s 828ms/step - loss: 0.0049 - acc: 0.8541 - recall: 0.4386 - precision: 0.9532 - f1_score: 0.7644 - val_loss: 0.0050 - val_acc: 0.8475 - val_recall: 0.4630 - val_precision: 0.9318 - val_f1_score: 0.7591
# Epoch 5/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0041 - acc: 0.8967 - recall: 0.4765 - precision: 0.9635 - f1_score: 0.8005
# Epoch 00005: val_f1_score improved from 0.75909 to 0.78006, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1817s 829ms/step - loss: 0.0041 - acc: 0.8967 - recall: 0.4765 - precision: 0.9635 - f1_score: 0.8005 - val_loss: 0.0045 - val_acc: 0.8722 - val_recall: 0.4870 - val_precision: 0.9360 - val_f1_score: 0.7801
# Epoch 6/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0036 - acc: 0.9242 - recall: 0.5035 - precision: 0.9714 - f1_score: 0.8235
# Epoch 00006: val_f1_score improved from 0.78006 to 0.79207, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1815s 828ms/step - loss: 0.0036 - acc: 0.9242 - recall: 0.5035 - precision: 0.9714 - f1_score: 0.8235 - val_loss: 0.0042 - val_acc: 0.8859 - val_recall: 0.4972 - val_precision: 0.9485 - val_f1_score: 0.7921
# Epoch 7/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0032 - acc: 0.9428 - recall: 0.5235 - precision: 0.9767 - f1_score: 0.8389
# Epoch 00007: val_f1_score improved from 0.79207 to 0.80097, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1813s 827ms/step - loss: 0.0032 - acc: 0.9428 - recall: 0.5235 - precision: 0.9767 - f1_score: 0.8389 - val_loss: 0.0039 - val_acc: 0.8967 - val_recall: 0.5155 - val_precision: 0.9493 - val_f1_score: 0.8010
# Epoch 8/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0029 - acc: 0.9554 - recall: 0.5376 - precision: 0.9809 - f1_score: 0.8491
# Epoch 00008: val_f1_score improved from 0.80097 to 0.80788, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1817s 829ms/step - loss: 0.0029 - acc: 0.9554 - recall: 0.5376 - precision: 0.9809 - f1_score: 0.8491 - val_loss: 0.0038 - val_acc: 0.9053 - val_recall: 0.5224 - val_precision: 0.9520 - val_f1_score: 0.8079
# Epoch 9/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9639 - recall: 0.5483 - precision: 0.9841 - f1_score: 0.8560
# Epoch 00009: val_f1_score improved from 0.80788 to 0.81580, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1818s 830ms/step - loss: 0.0028 - acc: 0.9639 - recall: 0.5483 - precision: 0.9841 - f1_score: 0.8560 - val_loss: 0.0036 - val_acc: 0.9148 - val_recall: 0.5323 - val_precision: 0.9573 - val_f1_score: 0.8158
# Epoch 10/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0026 - acc: 0.9700 - recall: 0.5556 - precision: 0.9862 - f1_score: 0.8608
# Epoch 00010: val_f1_score improved from 0.81580 to 0.81741, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1817s 829ms/step - loss: 0.0026 - acc: 0.9700 - recall: 0.5556 - precision: 0.9862 - f1_score: 0.8608 - val_loss: 0.0036 - val_acc: 0.9166 - val_recall: 0.5375 - val_precision: 0.9593 - val_f1_score: 0.8174
# Epoch 11/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0025 - acc: 0.9746 - recall: 0.5617 - precision: 0.9880 - f1_score: 0.8644
# Epoch 00011: val_f1_score improved from 0.81741 to 0.81962, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1826s 833ms/step - loss: 0.0025 - acc: 0.9746 - recall: 0.5617 - precision: 0.9880 - f1_score: 0.8644 - val_loss: 0.0035 - val_acc: 0.9193 - val_recall: 0.5377 - val_precision: 0.9630 - val_f1_score: 0.8196
# Epoch 12/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0024 - acc: 0.9781 - recall: 0.5661 - precision: 0.9894 - f1_score: 0.8670
# Epoch 00012: val_f1_score improved from 0.81962 to 0.82251, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1813s 827ms/step - loss: 0.0024 - acc: 0.9781 - recall: 0.5661 - precision: 0.9894 - f1_score: 0.8670 - val_loss: 0.0034 - val_acc: 0.9223 - val_recall: 0.5366 - val_precision: 0.9676 - val_f1_score: 0.8225
# Epoch 13/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0023 - acc: 0.9808 - recall: 0.5698 - precision: 0.9906 - f1_score: 0.8691
# Epoch 00013: val_f1_score improved from 0.82251 to 0.82624, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1830s 835ms/step - loss: 0.0023 - acc: 0.9808 - recall: 0.5698 - precision: 0.9906 - f1_score: 0.8691 - val_loss: 0.0033 - val_acc: 0.9272 - val_recall: 0.5519 - val_precision: 0.9659 - val_f1_score: 0.8262
# Epoch 14/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0023 - acc: 0.9830 - recall: 0.5723 - precision: 0.9916 - f1_score: 0.8708
# Epoch 00014: val_f1_score improved from 0.82624 to 0.82652, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1807s 825ms/step - loss: 0.0023 - acc: 0.9830 - recall: 0.5723 - precision: 0.9916 - f1_score: 0.8708 - val_loss: 0.0033 - val_acc: 0.9275 - val_recall: 0.5504 - val_precision: 0.9664 - val_f1_score: 0.8265
# Epoch 15/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0022 - acc: 0.9850 - recall: 0.5747 - precision: 0.9927 - f1_score: 0.8723
# Epoch 00015: val_f1_score improved from 0.82652 to 0.82866, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1842s 841ms/step - loss: 0.0022 - acc: 0.9850 - recall: 0.5747 - precision: 0.9927 - f1_score: 0.8723 - val_loss: 0.0032 - val_acc: 0.9302 - val_recall: 0.5665 - val_precision: 0.9659 - val_f1_score: 0.8287
# Epoch 16/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0022 - acc: 0.9862 - recall: 0.5764 - precision: 0.9930 - f1_score: 0.8732
# Epoch 00016: val_f1_score improved from 0.82866 to 0.83102, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1803s 823ms/step - loss: 0.0022 - acc: 0.9862 - recall: 0.5764 - precision: 0.9930 - f1_score: 0.8732 - val_loss: 0.0032 - val_acc: 0.9332 - val_recall: 0.5463 - val_precision: 0.9736 - val_f1_score: 0.8310
# Epoch 17/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0021 - acc: 0.9877 - recall: 0.5774 - precision: 0.9937 - f1_score: 0.8743
# Epoch 00017: val_f1_score did not improve from 0.83102
# 2191/2191 [==============================] - 1851s 845ms/step - loss: 0.0021 - acc: 0.9877 - recall: 0.5774 - precision: 0.9937 - f1_score: 0.8743 - val_loss: 0.0032 - val_acc: 0.9330 - val_recall: 0.5566 - val_precision: 0.9713 - val_f1_score: 0.8307
# Epoch 18/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0021 - acc: 0.9888 - recall: 0.5790 - precision: 0.9943 - f1_score: 0.8751
# Epoch 00018: val_f1_score did not improve from 0.83102
# 2191/2191 [==============================] - 1792s 818ms/step - loss: 0.0021 - acc: 0.9888 - recall: 0.5790 - precision: 0.9943 - f1_score: 0.8751 - val_loss: 0.0032 - val_acc: 0.9320 - val_recall: 0.5559 - val_precision: 0.9720 - val_f1_score: 0.8301
# Epoch 19/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0020 - acc: 0.9897 - recall: 0.5792 - precision: 0.9946 - f1_score: 0.8757
# Epoch 00019: val_f1_score improved from 0.83102 to 0.83352, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1855s 847ms/step - loss: 0.0020 - acc: 0.9897 - recall: 0.5792 - precision: 0.9946 - f1_score: 0.8757 - val_loss: 0.0031 - val_acc: 0.9362 - val_recall: 0.5590 - val_precision: 0.9747 - val_f1_score: 0.8335
# Epoch 20/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0020 - acc: 0.9905 - recall: 0.5804 - precision: 0.9950 - f1_score: 0.8763
# Epoch 00020: val_f1_score improved from 0.83352 to 0.83399, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1790s 817ms/step - loss: 0.0020 - acc: 0.9905 - recall: 0.5804 - precision: 0.9950 - f1_score: 0.8763 - val_loss: 0.0031 - val_acc: 0.9369 - val_recall: 0.5654 - val_precision: 0.9736 - val_f1_score: 0.8340
# Epoch 21/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0020 - acc: 0.9912 - recall: 0.5806 - precision: 0.9953 - f1_score: 0.8768
# Epoch 00021: val_f1_score improved from 0.83399 to 0.83462, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1834s 837ms/step - loss: 0.0020 - acc: 0.9912 - recall: 0.5806 - precision: 0.9953 - f1_score: 0.8768 - val_loss: 0.0031 - val_acc: 0.9378 - val_recall: 0.5678 - val_precision: 0.9730 - val_f1_score: 0.8346
# Epoch 22/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0020 - acc: 0.9917 - recall: 0.5808 - precision: 0.9955 - f1_score: 0.8772
# Epoch 00022: val_f1_score did not improve from 0.83462
# 2191/2191 [==============================] - 1806s 824ms/step - loss: 0.0020 - acc: 0.9917 - recall: 0.5808 - precision: 0.9955 - f1_score: 0.8772 - val_loss: 0.0031 - val_acc: 0.9367 - val_recall: 0.5581 - val_precision: 0.9745 - val_f1_score: 0.8338
# Epoch 23/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0019 - acc: 0.9924 - recall: 0.5814 - precision: 0.9959 - f1_score: 0.8777
# Epoch 00023: val_f1_score improved from 0.83462 to 0.83497, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1818s 830ms/step - loss: 0.0019 - acc: 0.9924 - recall: 0.5814 - precision: 0.9959 - f1_score: 0.8777 - val_loss: 0.0031 - val_acc: 0.9380 - val_recall: 0.5609 - val_precision: 0.9751 - val_f1_score: 0.8350
# Epoch 24/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0019 - acc: 0.9928 - recall: 0.5815 - precision: 0.9960 - f1_score: 0.8780
# Epoch 00024: val_f1_score improved from 0.83497 to 0.83636, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1815s 828ms/step - loss: 0.0019 - acc: 0.9928 - recall: 0.5815 - precision: 0.9960 - f1_score: 0.8780 - val_loss: 0.0030 - val_acc: 0.9397 - val_recall: 0.5664 - val_precision: 0.9755 - val_f1_score: 0.8364
# Epoch 25/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0019 - acc: 0.9934 - recall: 0.5816 - precision: 0.9964 - f1_score: 0.8784
# Epoch 00025: val_f1_score improved from 0.83636 to 0.83719, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1818s 830ms/step - loss: 0.0019 - acc: 0.9934 - recall: 0.5816 - precision: 0.9964 - f1_score: 0.8784 - val_loss: 0.0030 - val_acc: 0.9410 - val_recall: 0.5649 - val_precision: 0.9771 - val_f1_score: 0.8372
# Epoch 26/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0019 - acc: 0.9938 - recall: 0.5815 - precision: 0.9964 - f1_score: 0.8787
# Epoch 00026: val_f1_score improved from 0.83719 to 0.83790, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1809s 826ms/step - loss: 0.0019 - acc: 0.9938 - recall: 0.5815 - precision: 0.9964 - f1_score: 0.8787 - val_loss: 0.0029 - val_acc: 0.9417 - val_recall: 0.5615 - val_precision: 0.9767 - val_f1_score: 0.8379
# Epoch 27/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0019 - acc: 0.9944 - recall: 0.5812 - precision: 0.9967 - f1_score: 0.8791
# Epoch 00027: val_f1_score did not improve from 0.83790
# 2191/2191 [==============================] - 1815s 829ms/step - loss: 0.0019 - acc: 0.9944 - recall: 0.5812 - precision: 0.9967 - f1_score: 0.8791 - val_loss: 0.0030 - val_acc: 0.9416 - val_recall: 0.5668 - val_precision: 0.9769 - val_f1_score: 0.8377
# Epoch 28/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0019 - acc: 0.9943 - recall: 0.5813 - precision: 0.9968 - f1_score: 0.8791
# Epoch 00028: val_f1_score improved from 0.83790 to 0.83816, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1808s 825ms/step - loss: 0.0019 - acc: 0.9943 - recall: 0.5813 - precision: 0.9968 - f1_score: 0.8791 - val_loss: 0.0029 - val_acc: 0.9420 - val_recall: 0.5577 - val_precision: 0.9795 - val_f1_score: 0.8382
# Epoch 29/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9949 - recall: 0.5814 - precision: 0.9970 - f1_score: 0.8795
# Epoch 00029: val_f1_score improved from 0.83816 to 0.83945, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1817s 829ms/step - loss: 0.0018 - acc: 0.9949 - recall: 0.5814 - precision: 0.9970 - f1_score: 0.8795 - val_loss: 0.0030 - val_acc: 0.9436 - val_recall: 0.5616 - val_precision: 0.9785 - val_f1_score: 0.8395
# Epoch 30/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9951 - recall: 0.5812 - precision: 0.9972 - f1_score: 0.8797
# Epoch 00030: val_f1_score improved from 0.83945 to 0.84041, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1808s 825ms/step - loss: 0.0018 - acc: 0.9951 - recall: 0.5812 - precision: 0.9972 - f1_score: 0.8797 - val_loss: 0.0029 - val_acc: 0.9449 - val_recall: 0.5651 - val_precision: 0.9800 - val_f1_score: 0.8404
# Epoch 31/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9954 - recall: 0.5807 - precision: 0.9973 - f1_score: 0.8798
# Epoch 00031: val_f1_score did not improve from 0.84041
# 2191/2191 [==============================] - 1817s 829ms/step - loss: 0.0018 - acc: 0.9954 - recall: 0.5807 - precision: 0.9973 - f1_score: 0.8798 - val_loss: 0.0029 - val_acc: 0.9445 - val_recall: 0.5723 - val_precision: 0.9786 - val_f1_score: 0.8401
# Epoch 32/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9956 - recall: 0.5807 - precision: 0.9974 - f1_score: 0.8800
# Epoch 00032: val_f1_score improved from 0.84041 to 0.84065, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1823s 832ms/step - loss: 0.0018 - acc: 0.9956 - recall: 0.5807 - precision: 0.9974 - f1_score: 0.8800 - val_loss: 0.0029 - val_acc: 0.9454 - val_recall: 0.5657 - val_precision: 0.9786 - val_f1_score: 0.8406
# Epoch 33/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9959 - recall: 0.5804 - precision: 0.9975 - f1_score: 0.8802
# Epoch 00033: val_f1_score improved from 0.84065 to 0.84070, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1817s 829ms/step - loss: 0.0018 - acc: 0.9959 - recall: 0.5804 - precision: 0.9975 - f1_score: 0.8802 - val_loss: 0.0029 - val_acc: 0.9455 - val_recall: 0.5693 - val_precision: 0.9791 - val_f1_score: 0.8407
# Epoch 34/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9961 - recall: 0.5800 - precision: 0.9976 - f1_score: 0.8803
# Epoch 00034: val_f1_score improved from 0.84070 to 0.84118, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1841s 840ms/step - loss: 0.0018 - acc: 0.9961 - recall: 0.5800 - precision: 0.9976 - f1_score: 0.8803 - val_loss: 0.0029 - val_acc: 0.9459 - val_recall: 0.5717 - val_precision: 0.9788 - val_f1_score: 0.8412
# Epoch 35/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9962 - recall: 0.5800 - precision: 0.9976 - f1_score: 0.8804
# Epoch 00035: val_f1_score did not improve from 0.84118
# 2191/2191 [==============================] - 1807s 825ms/step - loss: 0.0018 - acc: 0.9962 - recall: 0.5800 - precision: 0.9976 - f1_score: 0.8804 - val_loss: 0.0029 - val_acc: 0.9450 - val_recall: 0.5672 - val_precision: 0.9785 - val_f1_score: 0.8403
# Epoch 36/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9965 - recall: 0.5798 - precision: 0.9978 - f1_score: 0.8806
# Epoch 00036: val_f1_score improved from 0.84118 to 0.84185, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1828s 834ms/step - loss: 0.0018 - acc: 0.9965 - recall: 0.5798 - precision: 0.9978 - f1_score: 0.8806 - val_loss: 0.0028 - val_acc: 0.9469 - val_recall: 0.5726 - val_precision: 0.9791 - val_f1_score: 0.8419
# Epoch 37/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9964 - recall: 0.5794 - precision: 0.9977 - f1_score: 0.8805
# Epoch 00037: val_f1_score improved from 0.84185 to 0.84190, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1805s 824ms/step - loss: 0.0018 - acc: 0.9964 - recall: 0.5794 - precision: 0.9977 - f1_score: 0.8805 - val_loss: 0.0028 - val_acc: 0.9468 - val_recall: 0.5618 - val_precision: 0.9802 - val_f1_score: 0.8419
# Epoch 38/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9967 - recall: 0.5791 - precision: 0.9979 - f1_score: 0.8807
# Epoch 00038: val_f1_score improved from 0.84190 to 0.84279, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1824s 833ms/step - loss: 0.0017 - acc: 0.9967 - recall: 0.5791 - precision: 0.9979 - f1_score: 0.8807 - val_loss: 0.0028 - val_acc: 0.9480 - val_recall: 0.5691 - val_precision: 0.9817 - val_f1_score: 0.8428
# Epoch 39/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9969 - recall: 0.5788 - precision: 0.9980 - f1_score: 0.8809
# Epoch 00039: val_f1_score did not improve from 0.84279
# 2191/2191 [==============================] - 1800s 821ms/step - loss: 0.0017 - acc: 0.9969 - recall: 0.5788 - precision: 0.9980 - f1_score: 0.8809 - val_loss: 0.0029 - val_acc: 0.9461 - val_recall: 0.5648 - val_precision: 0.9807 - val_f1_score: 0.8413
# Epoch 40/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9969 - recall: 0.5784 - precision: 0.9980 - f1_score: 0.8809
# Epoch 00040: val_f1_score did not improve from 0.84279
# 2191/2191 [==============================] - 1847s 843ms/step - loss: 0.0017 - acc: 0.9969 - recall: 0.5784 - precision: 0.9980 - f1_score: 0.8809 - val_loss: 0.0029 - val_acc: 0.9470 - val_recall: 0.5699 - val_precision: 0.9793 - val_f1_score: 0.8420
# Epoch 41/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9973 - recall: 0.5781 - precision: 0.9980 - f1_score: 0.8811
# Epoch 00041: val_f1_score did not improve from 0.84279
# 2191/2191 [==============================] - 1792s 818ms/step - loss: 0.0017 - acc: 0.9973 - recall: 0.5781 - precision: 0.9980 - f1_score: 0.8811 - val_loss: 0.0029 - val_acc: 0.9468 - val_recall: 0.5646 - val_precision: 0.9811 - val_f1_score: 0.8420
# Epoch 42/100
# 2191/2191 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9973 - recall: 0.5779 - precision: 0.9981 - f1_score: 0.8812
# Epoch 00042: val_f1_score improved from 0.84279 to 0.84330, saving model to /app/_data/models/dict_features/Eff2_260_260_1/Eff2_260_260_d6_2.h5
# 2191/2191 [==============================] - 1861s 849ms/step - loss: 0.0017 - acc: 0.9973 - recall: 0.5779 - precision: 0.9981 - f1_score: 0.8812 - val_loss: 0.0028 - val_acc: 0.9485 - val_recall: 0.5762 - val_precision: 0.9810 - val_f1_score: 0.8433
# Epoch 43/100
#    5/2191 [..............................] - ETA: 13:02 - loss: 0.0018 - acc: 0.9970 - recall: 0.5837 - precision: 0.9991 - f1_score: 0.8789
