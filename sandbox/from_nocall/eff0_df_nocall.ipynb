# %%
import os
import shutil
import warnings

import numpy as np
import pandas as pd
import plotly.graph_objects as go
import torchaudio

warnings.filterwarnings(action="ignore")
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
import json

import geopandas
import librosa
import librosa.display
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns
import soundfile
import tensorflow as tf
import tensorflow_addons as tfa
import torch

# %matplotlib inline
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from torchaudio.transforms import MelSpectrogram
from tqdm import tqdm

from src.MEL_Gen import MEL_Gen, Mel_Provider
from src.prepare_dataset import (
    choose_ids,
    make_dict_birds,
    make_intervals,
    make_intervals_upsampling,
    prepare_dataset,
)

# %%
SEED = 42
IMG_SIZE = 224
SAMPLE_RATE = 32000
N_FFT = 2048
SIGNAL_LENGTH = 5
FREQ_MIN = 0
FREQ_MAX = 16000
WIN_LENGHT = 1024
BATCH_SIZE = 50
list_drop = [
    "XC509721.ogg",
    "XC428067.ogg",
    "XC523831.ogg",
    "XC523960.ogg",
    "XC237870.ogg",
    "XC129924.ogg",
    "XC576851.ogg",
    "XC579430.ogg",
    "XC590621.ogg",
]

# %%
final = pd.read_csv("/app/_data/labels_nocall/nocall_predictions.csv")
nocall = pd.read_csv("/app/_data/labels_nocall/all_nocalls.csv")

# %%
all_audio_init = pd.read_csv("/app/_data/all_audio_initial.csv")
all_audio = all_audio_init.query("filename not in @list_drop").reset_index(drop=True)
all_audio = all_audio.query("year >=1980 and year<=2021").reset_index(drop=True)

all_audio.shape
# Out:
# (65128, 24)

# %% [markdown]
# # dict_birds and weights

# %%
dict_birds, all_audio = make_dict_birds(all_audio)

# %%
len(dict_birds)
# Out:
# 398

# %%
dict_weights = (1 / all_audio["primary_label"].value_counts()).to_dict()
all_audio["class_weights"] = all_audio["primary_label"].replace(dict_weights)
all_audio["class_weights"] = all_audio["class_weights"] * all_audio["rating"]

# %% [markdown]
# ## calls

# %%
drop_list_final = final[(final["bird"] == 1) & (final["nocall"] == 1)][
    "row_id"
].tolist()

# %%
final = final.query("row_id not in @drop_list_final")
final = final.query("bird == 1")

# %%
final = final.merge(
    all_audio[["filename", "primary_label", "class_weights"]], on="filename", how="left"
)

# %%
final_sample = final.sample(400000, weights="class_weights", random_state=SEED)

# %%
final_sample.sample()
# Out:
#          nocall  bird          row_id      filename  end_sec primary_label  \
# 1279190       0     1  XC117661_169_0  XC117661.ogg    169.0       kebtou1
#
#          class_weights
# 1279190       0.078125

# %%
final_sample = final_sample[
    ["row_id", "filename", "end_sec", "primary_label", "class_weights"]
].merge(
    all_audio[
        [
            "filename",
            "secondary_labels",
            "label_id",
            "secondary_labels_id",
            "duration",
            "rating",
            "year",
            "file_path",
            "sin_month",
            "cos_month",
            "sin_longitude",
            "cos_longitude",
            "latitude",
            "norm_latitude",
        ]
    ],
    on="filename",
    how="left",
)

# %%
final_sample
# Out:
#                 row_id      filename  end_sec primary_label  class_weights  \
# 0        XC423534_13_0  XC423534.ogg     13.0        gcrwar       0.027624
# 1       XC375498_428_0  XC375498.ogg    428.0        woothr       0.015284
# 2       XC478859_226_0  XC478859.ogg    226.0        rudtur       0.035714
# 3         XC63429_19_0   XC63429.ogg     19.0       orbeup1       0.027027
# 4       XC269518_504_0  XC269518.ogg    504.0        brnthr       0.030201
# ...                ...           ...      ...           ...            ...
# 399995   XC451992_45_0  XC451992.ogg     45.0        trokin       0.017361
# 399996  XC614092_188_0  XC614092.ogg    188.0        wiltur       0.050000
# 399997   XC353210_14_0  XC353210.ogg     14.0       whfpar1       0.044304
# 399998    XC161891_6_0  XC161891.ogg      6.0        coohaw       0.027523
# 399999   XC356296_74_0  XC356296.ogg     74.0        thbkin       0.037634
#
#                                   secondary_labels  label_id  \
# 0                                              NaN       143
# 1              yebcha spotow bkbmag1 wesmea cliswa       379
# 2                                           sander       290
# 3                                              NaN       234
# 4                                           rewbla        60
# ...                                            ...       ...
# 399995                                         NaN       341
# 399996                               moudov whwdov       376
# 399997                 whwdov normoc houspa houfin       366
# 399998                                         NaN       114
# 399999  annhum caltow ruckin houfin cowscj1 bewwre       336
#
#          secondary_labels_id     duration  rating  year  \
# 0                        NaN    18.796219     5.0  2018
# 1         382 319 33 357 100   504.804375     3.5  2017
# 2                        298  1976.908844     4.5  2018
# 3                        NaN    24.726000     4.0  2001
# 4                        271   596.749000     4.5  2015
# ...                      ...          ...     ...   ...
# 399995                   NaN    59.991312     5.0  2019
# 399996               214 372   304.645000     3.5  2020
# 399997       372 223 179 178   384.719469     3.5  2016
# 399998                   NaN    26.371719     3.0  2010
# 399999  13 79 285 178 116 32    98.992125     3.5  2017
#
#                                                 file_path     sin_month  \
# 0        /app/_data/train_short_audio/gcrwar/XC423534.ogg  1.224647e-16
# 1        /app/_data/train_short_audio/woothr/XC375498.ogg  1.224647e-16
# 2        /app/_data/train_short_audio/rudtur/XC478859.ogg -8.660254e-01
# 3        /app/_data/train_short_audio/orbeup1/XC63429.ogg -8.660254e-01
# 4        /app/_data/train_short_audio/brnthr/XC269518.ogg -5.000000e-01
# ...                                                   ...           ...
# 399995   /app/_data/train_short_audio/trokin/XC451992.ogg  5.000000e-01
# 399996   /app/_data/train_short_audio/wiltur/XC614092.ogg  8.660254e-01
# 399997  /app/_data/train_short_audio/whfpar1/XC353210.ogg  1.000000e+00
# 399998   /app/_data/train_short_audio/coohaw/XC161891.ogg -5.000000e-01
# 399999   /app/_data/train_short_audio/thbkin/XC356296.ogg  8.660254e-01
#
#            cos_month  sin_longitude  cos_longitude  latitude  norm_latitude
# 0      -1.000000e+00      -0.754768       0.655992  -14.6250       0.418750
# 1      -1.000000e+00      -0.965118      -0.261814   40.5886       0.725492
# 2      -5.000000e-01      -0.385751       0.922603   64.0818       0.856010
# 3       5.000000e-01      -0.948636       0.316371  -13.0501       0.427499
# 4      -8.660254e-01      -0.987984       0.154553   32.1779       0.678766
# ...              ...            ...            ...       ...            ...
# 399995  8.660254e-01      -0.642496       0.766289   -7.2395       0.459781
# 399996 -5.000000e-01      -0.944638      -0.328113   31.9060       0.677256
# 399997  6.123234e-17      -0.945887      -0.324497   27.0149       0.650083
# 399998 -8.660254e-01      -0.960682       0.277652   41.2004       0.728891
# 399999  5.000000e-01      -0.884570      -0.466408   34.1268       0.689593
#
# [400000 rows x 18 columns]

# %%
final_sample['primary_label'].value_counts()
# Out:
# normoc     3520
# yelgro     2924
# bulori     2721
# brnthr     2714
# cubthr     2412
#            ...
# gretin1     186
# whcpar      160
# wegspa1     133
# hofwoo1     130
# stvhum2      52
# Name: primary_label, Length: 397, dtype: int64

# %% [markdown]
# # nocall

# %%
nocall = nocall.drop_duplicates()

# %%
all_audio["class_weights"] = all_audio["class_weights"].astype("float32")

# %%
nocall = nocall.merge(
    all_audio[
        [
            "filename",
            "rating",
            "year",
            "sin_month",
            "cos_month",
            "sin_longitude",
            "cos_longitude",
            "latitude",
            "norm_latitude",
        ]
    ],
    on="filename",
    how="left",
).drop_duplicates()

# %%
nocall["label_id"] = dict_birds["nocall"]
nocall["secondary_labels_id"] = np.nan

# %%
nocall["class_weights"] = all_audio["class_weights"].median()

# %%
nocall['file_path'] = nocall['file_path'].str.replace('birdclef-2021/', '')

# %%
nocall_sample = nocall.sample(20000, random_state=SEED)

# %% [markdown]
# # concat

# %%
final_audio = (
    pd.concat(
        [final_sample, nocall_sample],
        axis=0,
        ignore_index=True,
    )
    .sample(frac=1, random_state=SEED)
    .reset_index(drop=True)
)
final_audio.shape
# Out:
# (420000, 20)

# %%
final_audio["primary_label"].value_counts().tail(20)
# Out:
# norsho     387
# grhcha1    386
# leasan     383
# sthwoo1    372
# bkbplo     362
# rebsap     353
# whimbr     332
# goowoo1    330
# lotduc     304
# sander     289
# rehbar1    259
# runwre1    236
# rthhum     219
# heptan     210
# bucmot2    202
# gretin1    186
# whcpar     160
# wegspa1    133
# hofwoo1    130
# stvhum2     52
# Name: primary_label, dtype: int64

# %%
train, valid = train_test_split(final_audio, train_size=0.8, random_state=SEED)
train = train.reset_index(drop=True)
valid = valid.reset_index(drop=True)

# %% [markdown]
# # MEL_Gen

# %%
NUM_CLASSES = len(dict_birds)
BATCH_SIZE = 410

# %%
mel_pr = Mel_Provider(
    n_fft=N_FFT,
    win_length=WIN_LENGHT,
    n_mels=IMG_SIZE,
    sample_rate=SAMPLE_RATE,
    mel_image_size=IMG_SIZE,
    min_frequency=FREQ_MIN,
    max_frequency=FREQ_MAX,
    signal_lenght=SIGNAL_LENGTH,
)

# %%
# shutil.rmtree('/app/_data/npy/short_mels')

# %%
gen_train = MEL_Gen(
    df=train,
    n_mels=IMG_SIZE,
    seed=SEED,
    sample_rate=SAMPLE_RATE,
    mel_image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    n_classes=NUM_CLASSES,
    signal_lenght=SIGNAL_LENGTH,
    mel_provider=mel_pr,
    wave_dir="/app/_data/npy/waves_npy/",
    short_mel_dir="/app/_data/npy/short_mels_224_uint8/",
    convert_to_rgb=True,
    shuffle=True,
    return_primary_labels=False,
    return_concat_labels=True,
    augment=False,
    img_dtype="uint8",
)
gen_valid = MEL_Gen(
    df=valid,
    n_mels=IMG_SIZE,
    seed=SEED,
    sample_rate=SAMPLE_RATE,
    mel_image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    n_classes=NUM_CLASSES,
    signal_lenght=SIGNAL_LENGTH,
    mel_provider=mel_pr,
    wave_dir="/app/_data/npy/waves_npy/",
    short_mel_dir="/app/_data/npy/short_mels_224_uint8/",
    convert_to_rgb=True,
    shuffle=False,
    return_primary_labels=False,
    return_concat_labels=True,
    augment=False,
    img_dtype="uint8",
)

# %% [markdown]
# # model

# %%
def get_model():
    inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    base_model = keras.applications.EfficientNetB0(
        weights="imagenet", include_top=False
    )
    x = base_model(inputs)
    x = keras.layers.GlobalAveragePooling2D(name="avg_pool")(x)
    x = keras.layers.Flatten(name="flatten")(x)
    outputs = keras.layers.Dense(NUM_CLASSES, activation="sigmoid")(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        loss="binary_crossentropy",
        optimizer=Adam(lr=0.0005),
        metrics=[
            "acc",
            keras.metrics.Recall(),
            keras.metrics.Precision(),
            tfa.metrics.F1Score(num_classes=NUM_CLASSES, average="micro"),
        ],
    )
    return model

policy = keras.mixed_precision.experimental.Policy("mixed_float16")
keras.mixed_precision.experimental.set_policy(policy)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3090, compute capability 8.6

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_f1_score",
        patience=12,
        restore_best_weights=True,
        verbose=1,
        mode="max",
    ),
    keras.callbacks.ModelCheckpoint(
        "/app/_data/models/from_nocall/Eff0_1/Eff0_1.h5",
        monitor="val_f1_score",
        verbose=1,
        save_best_only=True,
        save_weights_only=False,
        mode="max",
        save_freq="epoch",
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_f1_score",
        factor=0.9,
        patience=5,
        verbose=1,
        mode="max",
        min_delta=1e-4,
        min_lr=0.00000001,
    ),
    keras.callbacks.TensorBoard(log_dir="/app/.tensorboard/Eff0_1_nc/", histogram_freq=0),
    keras.callbacks.experimental.BackupAndRestore(
        "/app/_data/models/from_nocall/Eff0_1/backup/"
    ),
    keras.callbacks.TerminateOnNaN(),
]

# %%
model = get_model()
history = model.fit(
    gen_train,
    validation_data=gen_valid,
    epochs=100,
    steps_per_epoch=train.shape[0] // BATCH_SIZE,
    validation_steps=valid.shape[0] // BATCH_SIZE,
    verbose=1,
    workers=20,
    max_queue_size=50,
    callbacks=callbacks,
)
# Out:
# Epoch 1/100
#   1/819 [..............................] - ETA: 2s - loss: 0.7075 - acc: 0.0049 - recall: 0.4995 - precision: 0.0056 - f1_score: 0.0047WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 819/819 [==============================] - ETA: 0s - loss: 0.0268 - acc: 0.1108 - recall: 0.0189 - precision: 0.0606 - f1_score: 0.1083
# Epoch 00001: val_f1_score improved from -inf to 0.24712, saving model to /app/_data/models/from_nocall/Eff0_1/Eff0_1.h5
# 819/819 [==============================] - 1827s 2s/step - loss: 0.0268 - acc: 0.1108 - recall: 0.0189 - precision: 0.0606 - f1_score: 0.1083 - val_loss: 0.0294 - val_acc: 0.2915 - val_recall: 0.2382 - val_precision: 0.4625 - val_f1_score: 0.2471
# Epoch 2/100
# 819/819 [==============================] - ETA: 0s - loss: 0.0126 - acc: 0.5157 - recall: 0.1371 - precision: 0.9078 - f1_score: 0.4216
# Epoch 00002: val_f1_score improved from 0.24712 to 0.52181, saving model to /app/_data/models/from_nocall/Eff0_1/Eff0_1.h5
# 819/819 [==============================] - 670s 819ms/step - loss: 0.0126 - acc: 0.5157 - recall: 0.1371 - precision: 0.9078 - f1_score: 0.4216 - val_loss: 0.0108 - val_acc: 0.6481 - val_recall: 0.2513 - val_precision: 0.8724 - val_f1_score: 0.5218
# Epoch 3/100
# 819/819 [==============================] - ETA: 0s - loss: 0.0096 - acc: 0.7085 - recall: 0.2618 - precision: 0.9242 - f1_score: 0.5676
# Epoch 00003: val_f1_score improved from 0.52181 to 0.59953, saving model to /app/_data/models/from_nocall/Eff0_1/Eff0_1.h5
# 819/819 [==============================] - 742s 906ms/step - loss: 0.0096 - acc: 0.7085 - recall: 0.2618 - precision: 0.9242 - f1_score: 0.5676 - val_loss: 0.0088 - val_acc: 0.7510 - val_recall: 0.3062 - val_precision: 0.9187 - val_f1_score: 0.5995
# Epoch 4/100
# 819/819 [==============================] - ETA: 0s - loss: 0.
100
# 819/819 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9969 - recall: 0.5052 - precision: 0.9991 - f1_score: 0.7693
# Epoch 00064: val_f1_score did not improve from 0.73397
# 819/819 [==============================] - 850s 1s/step - loss: 0.0028 - acc: 0.9969 - recall: 0.5052 - precision: 0.9991 - f1_score: 0.7693 - val_loss: 0.0042 - val_acc: 0.9410 - val_recall: 0.4912 - val_precision: 0.9821 - val_f1_score: 0.7337
# Epoch 65/100
# 819/819 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9968 - recall: 0.5053 - precision: 0.9990 - f1_score: 0.7693
# Epoch 00065: val_f1_score improved from 0.73397 to 0.73400, saving model to /app/_data/models/from_nocall/Eff0_1/Eff0_1.h5
# 819/819 [==============================] - 845s 1s/step - loss: 0.0028 - acc: 0.9968 - recall: 0.5053 - precision: 0.9990 - f1_score: 0.7693 - val_loss: 0.0042 - val_acc: 0.9417 - val_recall: 0.4887 - val_precision: 0.9831 - val_f1_score: 0.7340
# Epoch 66/100
# 819/819 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9968 - recall: 0.5047 - precision: 0.9991 - f1_score: 0.7693
# Epoch 00066: val_f1_score improved from 0.73400 to 0.73507, saving model to /app/_data/models/from_nocall/Eff0_1/Eff0_1.h5
# 819/819 [==============================] - 850s 1s/step - loss: 0.0028 - acc: 0.9968 - recall: 0.5047 - precision: 0.9991 - f1_score: 0.7693 - val_loss: 0.0042 - val_acc: 0.9433 - val_recall: 0.4848 - val_precision: 0.9839 - val_f1_score: 0.7351
# Epoch 67/100
# 819/819 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9968 - recall: 0.5040 - precision: 0.9991 - f1_score: 0.7693
# Epoch 00067: val_f1_score did not improve from 0.73507
# 819/819 [==============================] - 848s 1s/step - loss: 0.0028 - acc: 0.9968 - recall: 0.5040 - precision: 0.9991 - f1_score: 0.7693 - val_loss: 0.0042 - val_acc: 0.9426 - val_recall: 0.4720 - val_precision: 0.9835 - val_f1_score: 0.7347
# Epoch 68/100
# 819/819 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9968 - recall: 0.5036 - precision: 0.9991 - f1_score: 0.7693
# Epoch 00068: val_f1_score did not improve from 0.73507
# 819/819 [==============================] - 853s 1s/step - loss: 0.0028 - acc: 0.9968 - recall: 0.5036 - precision: 0.9991 - f1_score: 0.7693 - val_loss: 0.0042 - val_acc: 0.9426 - val_recall: 0.4747 - val_precision: 0.9828 - val_f1_score: 0.7347
# Epoch 69/100
# 819/819 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9971 - recall: 0.5030 - precision: 0.9992 - f1_score: 0.7694
# Epoch 00069: val_f1_score improved from 0.73507 to 0.73515, saving model to /app/_data/models/from_nocall/Eff0_1/Eff0_1.h5
# 819/819 [==============================] - 840s 1s/step - loss: 0.0028 - acc: 0.9971 - recall: 0.5030 - precision: 0.9992 - f1_score: 0.7694 - val_loss: 0.0042 - val_acc: 0.9433 - val_recall: 0.4750 - val_precision: 0.9833 - val_f1_score: 0.7352
# Epoch 70/100
# 819/819 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9971 - recall: 0.5030 - precision: 0.9991 - f1_score: 0.7694
# Epoch 00070: val_f1_score did not improve from 0.73515
# 819/819 [==============================] - 840s 1s/step - loss: 0.0028 - acc: 0.9971 - recall: 0.5030 - precision: 0.9991 - f1_score: 0.7694 - val_loss: 0.0042 - val_acc: 0.9433 - val_recall: 0.4788 - val_precision: 0.9827 - val_f1_score: 0.7350
# Epoch 71/100
# 819/819 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9972 - recall: 0.5023 - precision: 0.9992 - f1_score: 0.7695
